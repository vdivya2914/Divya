# %%
import geocoder
from datetime import datetime

print("===== LOCATION TRACKER =====")

location = geocoder.ip("me")

if location.ok:
    latitude = location.lat
    longitude = location.lng
    address = location.address

    time = datetime.now()

    print("Date & Time :", time)
    print("Latitude    :", latitude)
    print("Longitude   :", longitude)
    print("Location    :", address)

    print("\nGoogle Maps Location:")
    print(
        "https://www.google.com/maps?q="
        + str(latitude)
        + ","
        + str(longitude)
    )

else:
    print("Unable to find location.")
# Out:
# ===== LOCATION TRACKER =====
# Date & Time : 2026-09-10 09:41:52.518031
# Latitude    : 41.2619
# Longitude   : -95.8608
# Location    : Council Bluffs, Iowa, US
#
# Google Maps Location:
# https://www.google.com/maps?q=41.2619,-95.8608
# /usr/local/lib/python3.13/dist-packages/geocoder/uscensus.py:36: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('^\d+', self.address, re.UNICODE)
